# %%
from datetime import datetime

now = datetime.now()


print("Current year:")
print(now.strftime("%H-%M-%S"))

print("\nCurrent Date:")
print(now.strftime("%d-%m-%Y"))

print("\nDay")
print(now.strftime("%A"))

print("\nMonth")
print(now.strftime("%B"))
# Out:
# Current year:
# 03-05-09
#
# Current Date:
# 03-06-2026
#
# Day
# Wednesday
#
# Month
# June

# %%
print("Today is",now.strftime("%A"))
print("Current month is",now.strftime("%B"))
print("Today is",now.year)
# Out:
# Today is Wednesday
# Current month is June
# Today is 2026
